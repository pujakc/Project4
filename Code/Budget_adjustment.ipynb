# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import statistics

from sklearn.linear_model import LinearRegression, Lasso, LassoCV

from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier
from sklearn.model_selection import train_test_split, GridSearchCV

from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, RandomForestClassifier, ExtraTreesClassifier, AdaBoostRegressor, GradientBoostingRegressor, AdaBoostClassifier, GradientBoostingClassifier, BaggingRegressor, BaggingClassifier

pd.options.display.float_format = '{:,.2f}'.format
pd.pandas.set_option('display.max_rows', None)
pd.pandas.set_option('display.max_columns', None)
import time

# %%
df = pd.read_csv('./Data/imputed.csv')

# %% [markdown]
# ####  Read the inflation adjustment Consumer Price Index for All Urban Consumers (CPI-U) file to get the CPI  for adjusting budget and gross

# %%
file = '../Project4/Data/SeriesReport-20240509191709_137c61.xlsx'

bls = pd.read_excel(io = file)
# Out:
# C:\Users\david\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df.head(2)
# Out:
#               name  rating      genre  year  score      votes  \
# 0      The Shining    4.00      Drama  1980   8.40 927,000.00
# 1  The Blue Lagoon    4.00  Adventure  1980   5.80  65,000.00
#
#           director                   writer            star         country  \
# 0  Stanley Kubrick             Stephen King  Jack Nicholson  United Kingdom
# 1   Randal Kleiser  Henry De Vere Stacpoole  Brooke Shields   United States
#
#          budget         gross            company  runtime month  \
# 0 19,000,000.00 46,998,772.00       Warner Bros.   146.00  June
# 1  4,500,000.00 58,853,106.00  Columbia Pictures   104.00  July
#
#    rating_imputed  budget_imputed
# 0               0               0
# 1               0               0

# %%
df.shape
# Out:
# (7475, 17)

# %%
df.isnull().sum()
# Out:
# name              0
# rating            0
# genre             0
# year              0
# score             0
# votes             0
# director          0
# writer            0
# star              0
# country           0
# budget            0
# gross             0
# company           0
# runtime           0
# month             0
# rating_imputed    0
# budget_imputed    0
# dtype: int64

# %%
df.dtypes
# Out:
# name               object
# rating            float64
# genre              object
# year                int64
# score             float64
# votes             float64
# director           object
# writer             object
# star               object
# country            object
# budget            float64
# gross             float64
# company            object
# runtime           float64
# month              object
# rating_imputed      int64
# budget_imputed      int64
# dtype: object

# %%
bls.shape
# Out:
# (53, 15)

# %%
bls.head()
# Out:
#   Consumer Price Index for All Urban Consumers (CPI-U)  \
# 0                                Original Data Value
# 1                                                NaN
# 2                                         Series Id:
# 3                            Not Seasonally Adjusted
# 4                                      Series Title:
#
#                                           Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                                NaN        NaN        NaN
# 1                                                NaN        NaN        NaN
# 2                                        CUUR0000SA0        NaN        NaN
# 3                                                NaN        NaN        NaN
# 4  All items in U.S. city average, all urban cons...        NaN        NaN
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14
# 0         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN

# %%
# Get all the rows since 1980
since80 = bls[11:]
since80.head()
# Out:
#    Consumer Price Index for All Urban Consumers (CPI-U) Unnamed: 1 Unnamed: 2  \
# 11                                               1980        77.80      78.90
# 12                                               1981           87      87.90
# 13                                               1982        94.30      94.60
# 14                                               1983        97.80      97.90
# 15                                               1984       101.90     102.40
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 11      80.10         81      81.80      82.70      82.70      83.30
# 12      88.50      89.10      89.80      90.60      91.60      92.30
# 13      94.50      94.90      95.80         97      97.50      97.70
# 14      97.90      98.60      99.20      99.50      99.90     100.20
# 15     102.60     103.10     103.40     103.70     104.10     104.50
#
#    Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14
# 11         84       84.80       85.50       86.30         NaN         NaN
# 12      93.20       93.40       93.70          94         NaN         NaN
# 13      97.90       98.20          98       97.60         NaN         NaN
# 14     100.70         101      101.20      101.30         NaN         NaN
# 15        105      105.30      105.30      105.30      102.90      104.90

# %%
type(bls)
# Out:
# pandas.core.frame.DataFrame

# %%
# Row 10 is the column names
cols = bls.iloc[10]
cols
# Out:
# Consumer Price Index for All Urban Consumers (CPI-U)     Year
# Unnamed: 1                                                Jan
# Unnamed: 2                                                Feb
# Unnamed: 3                                                Mar
# Unnamed: 4                                                Apr
# Unnamed: 5                                                May
# Unnamed: 6                                                Jun
# Unnamed: 7                                                Jul
# Unnamed: 8                                                Aug
# Unnamed: 9                                                Sep
# Unnamed: 10                                               Oct
# Unnamed: 11                                               Nov
# Unnamed: 12                                               Dec
# Unnamed: 13                                             HALF1
# Unnamed: 14                                             HALF2
# Name: 10, dtype: object

# %%
# Get all the rows since 1980
since80 = bls[11:]
since80.head()
# Out:
#    Consumer Price Index for All Urban Consumers (CPI-U) Unnamed: 1 Unnamed: 2  \
# 11                                               1980        77.80      78.90
# 12                                               1981           87      87.90
# 13                                               1982        94.30      94.60
# 14                                               1983        97.80      97.90
# 15                                               1984       101.90     102.40
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 11      80.10         81      81.80      82.70      82.70      83.30
# 12      88.50      89.10      89.80      90.60      91.60      92.30
# 13      94.50      94.90      95.80         97      97.50      97.70
# 14      97.90      98.60      99.20      99.50      99.90     100.20
# 15     102.60     103.10     103.40     103.70     104.10     104.50
#
#    Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14
# 11         84       84.80       85.50       86.30         NaN         NaN
# 12      93.20       93.40       93.70          94         NaN         NaN
# 13      97.90       98.20          98       97.60         NaN         NaN
# 14     100.70         101      101.20      101.30         NaN         NaN
# 15        105      105.30      105.30      105.30      102.90      104.90

# %%
since80 = since80.rename(columns = cols)
since80.head()
# Out:
#     Year    Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep  \
# 11  1980  77.80  78.90  80.10     81  81.80  82.70  82.70  83.30     84
# 12  1981     87  87.90  88.50  89.10  89.80  90.60  91.60  92.30  93.20
# 13  1982  94.30  94.60  94.50  94.90  95.80     97  97.50  97.70  97.90
# 14  1983  97.80  97.90  97.90  98.60  99.20  99.50  99.90 100.20 100.70
# 15  1984 101.90 102.40 102.60 103.10 103.40 103.70 104.10 104.50    105
#
#       Oct    Nov    Dec  HALF1  HALF2
# 11  84.80  85.50  86.30    NaN    NaN
# 12  93.40  93.70     94    NaN    NaN
# 13  98.20     98  97.60    NaN    NaN
# 14    101 101.20 101.30    NaN    NaN
# 15 105.30 105.30 105.30 102.90 104.90

# %%
since80 = since80.drop(columns = ['HALF1', 'HALF2'])

# %%
since80.head()
# Out:
#     Year    Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep  \
# 11  1980  77.80  78.90  80.10     81  81.80  82.70  82.70  83.30     84
# 12  1981     87  87.90  88.50  89.10  89.80  90.60  91.60  92.30  93.20
# 13  1982  94.30  94.60  94.50  94.90  95.80     97  97.50  97.70  97.90
# 14  1983  97.80  97.90  97.90  98.60  99.20  99.50  99.90 100.20 100.70
# 15  1984 101.90 102.40 102.60 103.10 103.40 103.70 104.10 104.50    105
#
#       Oct    Nov    Dec
# 11  84.80  85.50  86.30
# 12  93.40  93.70     94
# 13  98.20     98  97.60
# 14    101 101.20 101.30
# 15 105.30 105.30 105.30

# %%
# Need to map month names so when we match it to the clean.csv, it can match on month and year
month_map = {'Jan' : 'January',
            'Feb' : 'February', 
            'Mar' : 'March',
            'Apr' : 'April',
            'May' : 'May', 
            'Jun' : 'June',
            'Jul' : 'July',
            'Aug' : 'August',
            'Sep' : 'September',
            'Oct' : 'October',
            'Nov' : 'November',
            'Dec' : 'December'}

# %%
since80.rename(mapper = month_map, axis = 1, inplace = True)

# %%
since80.head(1)
# Out:
#     Year January February March April   May  June  July August September  \
# 11  1980   77.80    78.90 80.10    81 81.80 82.70 82.70  83.30        84
#
#    October November December
# 11   84.80    85.50    86.30

# %%
since80.set_index('Year', inplace = True)
since80.head(3)
# Out:
#      January February March April   May  June  July August September October  \
# Year
# 1980   77.80    78.90 80.10    81 81.80 82.70 82.70  83.30        84   84.80
# 1981      87    87.90 88.50 89.10 89.80 90.60 91.60  92.30     93.20   93.40
# 1982   94.30    94.60 94.50 94.90 95.80    97 97.50  97.70     97.90   98.20
#
#      November December
# Year
# 1980    85.50    86.30
# 1981    93.70       94
# 1982       98    97.60

# %%
since80.tail()
# Out:
#      January February  March  April    May   June   July August September  \
# Year
# 2017  242.84   243.60 243.80 244.52 244.73 244.96 244.79 245.52    246.82
# 2018  247.87   248.99 249.55 250.55 251.59 251.99 252.01 252.15    252.44
# 2019  251.71   252.78 254.20 255.55 256.09 256.14 256.57 256.56    256.76
# 2020  257.97   258.68 258.12 256.39 256.39 257.80 259.10 259.92    260.28
# 2021  261.58   263.01 264.88 267.05 269.19 271.70 273.00 273.57    274.31
#
#      October November December
# Year
# 2017  246.66   246.67   246.52
# 2018  252.88   252.04   251.23
# 2019  257.35   257.21   256.97
# 2020  260.39   260.23   260.47
# 2021  276.59   277.95   278.80

# %%
bls_dict = since80.to_dict()

# %%
#function to get inflation adjustment factor for each month of a year. We are considering Decemeber 2020 as reference year 

def get_inflation_adj_val(year, month):
    CPI_ref_year = bls_dict['December'][2020]
    CPI_base_year = bls_dict[month][year]
    Inflation_factor = CPI_ref_year/ bls_dict[month][year]                               
    return Inflation_factor

# %%
print(bls_dict['December'][2020])
print(bls_dict['July'][2018])
print((bls_dict['December'][2020])/(bls_dict['July'][2018]))

get_inflation_adj_val(2018, 'July')
# Out:
# 260.474
# 252.006
# 1.0336023745466378
# 1.0336023745466378

# %%
bls_dict['December'][2020]/(bls_dict['June'][1980])
# Out:
# 3.1496251511487303

# %%
#add inf_adjmnt_value column to the dataframe by  applying get_inflation_adj_val to each row of  the data frame  
df['inf_adjmnt_value'] = df.apply(lambda x: get_inflation_adj_val(x['year'], x['month']), axis=1)

# %%
df[['name','year','month','inf_adjmnt_value']].head(3)
# Out:
#                                              name  year month  \
# 0                                     The Shining  1980  June
# 1                                 The Blue Lagoon  1980  July
# 2  Star Wars: Episode V - The Empire Strikes Back  1980  June
#
#    inf_adjmnt_value
# 0              3.15
# 1              3.15
# 2              3.15

# %%
df[df['year'] == 1983].head()
# Out:
#                                            name  rating      genre  year  \
# 304                                    Scarface    4.00      Crime  1983
# 305                               The Outsiders    2.00      Crime  1983
# 306  Star Wars: Episode VI - Return of the Jedi    2.00     Action  1983
# 307                              Risky Business    4.00     Comedy  1983
# 308                 National Lampoon's Vacation    4.00  Adventure  1983
#
#      score      votes              director           writer  \
# 304   8.30 766,000.00        Brian De Palma     Oliver Stone
# 305   7.10  78,000.00  Francis Ford Coppola  Kathleen Rowell
# 306   8.30 973,000.00      Richard Marquand  Lawrence Kasdan
# 307   6.80  83,000.00         Paul Brickman    Paul Brickman
# 308   7.40 100,000.00          Harold Ramis      John Hughes
#
#                  star        country        budget          gross  \
# 304         Al Pacino  United States 25,000,000.00  65,884,703.00
# 305  C. Thomas Howell  United States 10,000,000.00  25,697,647.00
# 306       Mark Hamill  United States 32,500,000.00 475,106,177.00
# 307        Tom Cruise  United States  6,200,000.00  63,541,777.00
# 308       Chevy Chase  United States 15,000,000.00  61,399,552.00
#
#                 company  runtime     month  rating_imputed  budget_imputed  \
# 304  Universal Pictures   170.00  December               0               0
# 305    Zoetrope Studios    91.00     March               0               0
# 306           Lucasfilm   131.00       May               0               0
# 307  The Geffen Company    99.00    August               0               0
# 308    National Lampoon    98.00      July               0               0
#
#      inf_adjmnt_value    budget_adj        gross_adj
# 304              2.57 64,282,823.30   169,410,188.84
# 305              2.66 26,606,128.70    68,371,490.34
# 306              2.63 85,336,743.95 1,247,508,128.51
# 307              2.60 16,117,153.69   165,179,449.32
# 308              2.61 39,110,210.21   160,089,959.04

# %%
df['budget_adj'] = df['budget']* df['inf_adjmnt_value']
df['gross_adj'] = df['gross']* df['inf_adjmnt_value']

# %%
df.head(5)
# Out:
#                                              name  rating      genre  year  \
# 0                                     The Shining    4.00      Drama  1980
# 1                                 The Blue Lagoon    4.00  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back    2.00     Action  1980
# 3                                       Airplane!    2.00     Comedy  1980
# 4                                      Caddyshack    4.00     Comedy  1980
#
#    score        votes         director                   writer  \
# 0   8.40   927,000.00  Stanley Kubrick             Stephen King
# 1   5.80    65,000.00   Randal Kleiser  Henry De Vere Stacpoole
# 2   8.70 1,200,000.00   Irvin Kershner           Leigh Brackett
# 3   7.70   221,000.00     Jim Abrahams             Jim Abrahams
# 4   7.30   108,000.00     Harold Ramis       Brian Doyle-Murray
#
#              star         country        budget          gross  \
# 0  Jack Nicholson  United Kingdom 19,000,000.00  46,998,772.00
# 1  Brooke Shields   United States  4,500,000.00  58,853,106.00
# 2     Mark Hamill   United States 18,000,000.00 538,375,067.00
# 3     Robert Hays   United States  3,500,000.00  83,453,539.00
# 4     Chevy Chase   United States  6,000,000.00  39,846,344.00
#
#               company  runtime month  rating_imputed  budget_imputed  \
# 0        Warner Bros.   146.00  June               0               0
# 1   Columbia Pictures   104.00  July               0               0
# 2           Lucasfilm   124.00  June               0               0
# 3  Paramount Pictures    88.00  July               0               0
# 4      Orion Pictures    98.00  July               0               0
#
#    inf_adjmnt_value    budget_adj        gross_adj
# 0              3.15 59,842,877.87   148,028,514.36
# 1              3.15 14,173,313.18   185,365,222.88
# 2              3.15 56,693,252.72 1,695,679,651.77
# 3              3.15 11,023,688.03   262,847,365.39
# 4              3.15 18,897,750.91   125,501,047.24

# %%
df.tail()
# Out:
#                    name  rating   genre  year  score    votes  \
# 7470  The Eight Hundred    6.00  Action  2020   6.80 3,700.00
# 7471         The Quarry    4.00   Crime  2020   5.40 2,400.00
# 7472              Tulsa    3.00  Comedy  2020   5.00   294.00
# 7473               Leap    1.00   Drama  2020   6.70   903.00
# 7474          I Am Fear    6.00  Horror  2020   3.40   447.00
#
#                director         writer             star        country  \
# 7470            Hu Guan        Hu Guan  Zhi-zhong Huang          China
# 7471        Scott Teems    Scott Teems     Shea Whigham  United States
# 7472        Scott Pryor    Scott Pryor      Scott Pryor  United States
# 7473  Peter Ho-Sun Chan       Ji Zhang          Gong Li          China
# 7474      Kevin Shulman  Kevin Shulman   Kristina Klebe  United States
#
#             budget          gross                              company  \
# 7470 80,000,000.00 461,421,559.00  Beijing Diqi Yinxiang Entertainment
# 7471 13,277,500.00       3,661.00                     Prowess Pictures
# 7472 22,769,550.00     413,378.00                  Pryor Entertainment
# 7473 42,354,500.00  25,818,882.00                          We Pictures
# 7474 14,842,150.00      13,266.00                        Roxwell Films
#
#       runtime      month  rating_imputed  budget_imputed  inf_adjmnt_value  \
# 7470   149.00     August               0               0              1.00
# 7471    98.00      April               0               1              1.02
# 7472   120.00       June               0               1              1.01
# 7473   135.00  September               0               1              1.00
# 7474    87.00      March               0               1              1.01
#
#         budget_adj      gross_adj
# 7470 80,171,130.90 462,408,602.56
# 7471 13,489,048.03       3,719.33
# 7472 23,005,992.18     417,670.57
# 7473 42,386,068.98  25,838,126.13
# 7474 14,977,797.41      13,387.24

# %%
df[['name', 'budget','budget_adj', 'year', 'month', 'gross','gross_adj']].head()
# Out:
#                                              name        budget    budget_adj  \
# 0                                     The Shining 19,000,000.00 59,842,877.87
# 1                                 The Blue Lagoon  4,500,000.00 14,173,313.18
# 2  Star Wars: Episode V - The Empire Strikes Back 18,000,000.00 56,693,252.72
# 3                                       Airplane!  3,500,000.00 11,023,688.03
# 4                                      Caddyshack  6,000,000.00 18,897,750.91
#
#    year month          gross        gross_adj
# 0  1980  June  46,998,772.00   148,028,514.36
# 1  1980  July  58,853,106.00   185,365,222.88
# 2  1980  June 538,375,067.00 1,695,679,651.77
# 3  1980  July  83,453,539.00   262,847,365.39
# 4  1980  July  39,846,344.00   125,501,047.24

# %%
df['profit'] = df['gross'] - df['budget']
df['profit_adj'] = df['gross_adj'] - df['budget_adj']

# %%
df.head()
# Out:
#                                              name  rating      genre  year  \
# 0                                     The Shining    4.00      Drama  1980
# 1                                 The Blue Lagoon    4.00  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back    2.00     Action  1980
# 3                                       Airplane!    2.00     Comedy  1980
# 4                                      Caddyshack    4.00     Comedy  1980
#
#    score        votes         director                   writer  \
# 0   8.40   927,000.00  Stanley Kubrick             Stephen King
# 1   5.80    65,000.00   Randal Kleiser  Henry De Vere Stacpoole
# 2   8.70 1,200,000.00   Irvin Kershner           Leigh Brackett
# 3   7.70   221,000.00     Jim Abrahams             Jim Abrahams
# 4   7.30   108,000.00     Harold Ramis       Brian Doyle-Murray
#
#              star         country        budget          gross  \
# 0  Jack Nicholson  United Kingdom 19,000,000.00  46,998,772.00
# 1  Brooke Shields   United States  4,500,000.00  58,853,106.00
# 2     Mark Hamill   United States 18,000,000.00 538,375,067.00
# 3     Robert Hays   United States  3,500,000.00  83,453,539.00
# 4     Chevy Chase   United States  6,000,000.00  39,846,344.00
#
#               company  runtime month  rating_imputed  budget_imputed  \
# 0        Warner Bros.   146.00  June               0               0
# 1   Columbia Pictures   104.00  July               0               0
# 2           Lucasfilm   124.00  June               0               0
# 3  Paramount Pictures    88.00  July               0               0
# 4      Orion Pictures    98.00  July               0               0
#
#    inf_adjmnt_value    budget_adj        gross_adj         profit  \
# 0              3.15 59,842,877.87   148,028,514.36  27,998,772.00
# 1              3.15 14,173,313.18   185,365,222.88  54,353,106.00
# 2              3.15 56,693,252.72 1,695,679,651.77 520,375,067.00
# 3              3.15 11,023,688.03   262,847,365.39  79,953,539.00
# 4              3.15 18,897,750.91   125,501,047.24  33,846,344.00
#
#         profit_adj
# 0    88,185,636.49
# 1   171,191,909.70
# 2 1,638,986,399.05
# 3   251,823,677.36
# 4   106,603,296.34

# %%
df_sorted = df.sort_values(by = 'rating')

plt.figure(figsize = (10,10))
sns.boxplot(data = df_sorted, x = 'rating', y = 'budget')

plt.xlabel('Rating', fontsize = 15)
plt.ylabel('Budget in Hundreds of Millions of Dollars', fontsize = 15)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.title('Movie Budget by Rating after Inflation Adjustment', fontsize = 20)

plt.savefig('./Images/movie_budget_by_rating_after_inflation_adj.png', dpi = 192)

# %%
genre_sort = df.sort_values(by = 'genre')

plt.figure(figsize = (10,10))
sns.boxplot(data = genre_sort, x = 'genre', y = 'budget')

plt.xlabel('Genre', fontsize = 15)
plt.ylabel('Budget in Hundreds of Millions', fontsize = 15)
plt.xticks(fontsize = 14, rotation = 90)
plt.yticks(fontsize = 14)
plt.title('Movie Budget by Genre after Inflation Adjustment', fontsize = 20)

plt.savefig('./Images/movie_budget_by_genre_after_inflation_adjustment.png', dpi = 192);

# %%
import requests
import json
import prettytable

import pprint

# %%
#Code comes from https://www.bls.gov/developers/api_python.htm#python2

headers = {'Content-type': 'application/json'}
data = json.dumps({"seriesid": ['CUUR0000SA0','SUUR0000SA0'],"startyear":"1979", "endyear":"2021"}) # Changed years to 1979 and 2021 to make sure it captures everything in our data set
p = requests.post('https://api.bls.gov/publicAPI/v2/timeseries/data/', data=data, headers=headers)
json_data = json.loads(p.text)
for series in json_data['Results']['series']:
    x=prettytable.PrettyTable(["series id","year","period","value","footnotes"])
    seriesId = series['seriesID']
    for item in series['data']:
        year = item['year']
        period = item['period']
        value = item['value']
        footnotes=""
        for footnote in item['footnotes']:
            if footnote:
                footnotes = footnotes + footnote['text'] + ','
        if 'M01' <= period <= 'M12':
            x.add_row([seriesId,year,period,value,footnotes[0:-1]])
    output = open(seriesId + '.txt','w')
    output.write (x.get_string())
    output.close()

# %%
import requests
import json
import prettytable
headers = {'Content-type': 'application/json'}
data = json.dumps({"seriesid": ['CUUR0000SA0','SUUR0000SA0'],"startyear":"1979", "endyear":"2021"})
p = requests.post('https://api.bls.gov/publicAPI/v1/timeseries/data/', data=data, headers=headers)
json_data = json.loads(p.text)
for series in json_data['Results']['series']:
    x=prettytable.PrettyTable(["series id","year","period","value","footnotes"])
    seriesId = series['seriesID']
    for item in series['data']:
        year = item['year']
        period = item['period']
        value = item['value']
        footnotes=""
        for footnote in item['footnotes']:
            if footnote:
                footnotes = footnotes + footnote['text'] + ','
    
        if 'M01' <= period <= 'M12':
            x.add_row([seriesId,year,period,value,footnotes[0:-1]])
    output = open(seriesId + '.txt','w')
    output.write (x.get_string())
    output.close()

# %%
x
# Out:
# +-----------+------+--------+-------+-----------+
# | series id | year | period | value | footnotes |
# +-----------+------+--------+-------+-----------+
# +-----------+------+--------+-------+-----------+

# %%
output
# Out:
# <_io.TextIOWrapper name='SUUR0000SA0.txt' mode='w' encoding='cp1252'>

# %%
p
# Out:
# <Response [200]>

# %%
data
# Out:
# '{"seriesid": ["CUUR0000SA0", "SUUR0000SA0"], "startyear": "1979", "endyear": "2021"}'

# %%
json_data
# Out:
# {'status': 'REQUEST_SUCCEEDED',
#  'responseTime': 251,
#  'message': ['Year range has been reduced to the system-allowed limit of 10 years.',
#   'No Data Available for Series SUUR0000SA0 Year: 1979',
#   'No Data Available for Series SUUR0000SA0 Year: 1980',
#   'No Data Available for Series SUUR0000SA0 Year: 1981',
#   'No Data Available for Series SUUR0000SA0 Year: 1982',
#   'No Data Available for Series SUUR0000SA0 Year: 1983',
#   'No Data Available for Series SUUR0000SA0 Year: 1984',
#   'No Data Available for Series SUUR0000SA0 Year: 1985',
#   'No Data Available for Series SUUR0000SA0 Year: 1986',
#   'No Data Available for Series SUUR0000SA0 Year: 1987',
#   'No Data Available for Series SUUR0000SA0 Year: 1988'],
#  'Results': {'series': [{'seriesID': 'CUUR0000SA0',
#     'data': [{'year': '1988',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '120.5',
#       'footnotes': [{}]},
#      {'year': '1988',
#       'period': 'M11',
# ...
